# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/intern/saved_models')

# %%
pwd
# Out:
# '/content/drive/MyDrive/intern/saved_models'

# %%
import keras
import tensorflow as tf
import pathlib

# %%
model1 = keras.models.load_model('fruits_classification_model')
model2 = keras.models.load_model('fruits_classification_model.h5')
model3 = keras.models.load_model('leaves_classification_model')
model4 = keras.models.load_model('leaves_classification_model.h5')

# %%
import pathlib

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model1)
tflite_model = converter.convert()

tflite_model_file = pathlib.Path('tflite_models/fruits_model1.tflite')
tflite_model_file.write_bytes(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpkth0sym9/assets
# INFO:tensorflow:Assets written to: /tmp/tmpkth0sym9/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 691864

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model2)
tflite_model = converter.convert()

tflite_model_file = pathlib.Path('tflite_models/fruits_model2.tflite')
tflite_model_file.write_bytes(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpqoybb2ow/assets
# INFO:tensorflow:Assets written to: /tmp/tmpqoybb2ow/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 691864

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model3)
tflite_model = converter.convert()

tflite_model_file = pathlib.Path('tflite_models/leaves_model1.tflite')
tflite_model_file.write_bytes(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpg7veqw15/assets
# INFO:tensorflow:Assets written to: /tmp/tmpg7veqw15/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 691864

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model4)
tflite_model = converter.convert()

tflite_model_file = pathlib.Path('tflite_models/leaves_model2.tflite')
tflite_model_file.write_bytes(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpfatnj9qp/assets
# INFO:tensorflow:Assets written to: /tmp/tmpfatnj9qp/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 691864

# %%
combined_model = keras.models.load_model('/content/drive/MyDrive/intern/saved_models/joint_leaves_fruits_classification_model')

converter = tf.lite.TFLiteConverter.from_keras_model(combined_model)
tflite_model = converter.convert()

tflite_model_file = pathlib.Path('tflite_models/combined_model.tflite')
tflite_model_file.write_bytes(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpqf51mctd/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 692700
