# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !sudo apt -y install libportaudio2
# !pip install -q tflite-model-maker
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   libportaudio2
# 0 upgraded, 1 newly installed, 0 to remove and 62 not upgraded.
# Need to get 64.6 kB of archives.
# After this operation, 215 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libportaudio2 amd64 19.6.0-1 [64.6 kB]
# Fetched 64.6 kB in 0s (227 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
import os

import numpy as np

import tensorflow as tf
assert tf.__version__.startswith('2')

from tflite_model_maker import model_spec
from tflite_model_maker import image_classifier
from tflite_model_maker.config import ExportFormat
from tflite_model_maker.config import QuantizationConfig
from tflite_model_maker.image_classifier import DataLoader

import matplotlib.pyplot as plt

# %%
os.chdir('/content/drive/MyDrive/intern/saved_models')

# %%
data = DataLoader.from_folder('/content/drive/MyDrive/intern/katunda_dataset/fruits_dataset')
train_data, test_data = data.split(0.8)
model = image_classifier.create(train_data)
loss, accuracy = model.evaluate(test_data)
model.export('fruit_classifier.tflite', 'fruit_labels.txt')
# Out:
# INFO:tensorflow:Load image with size: 2992, num_label: 3, labels: Fruit_Brownspot, Fruit_Healthy, Fruit_Woodiness.
# INFO:tensorflow:Load image with size: 2992, num_label: 3, labels: Fruit_Brownspot, Fruit_Healthy, Fruit_Woodiness.
# INFO:tensorflow:Retraining the models...
# INFO:tensorflow:Retraining the models...
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hub_keras_layer_v1v2_2 (Hub  (None, 1280)             3413024
#  KerasLayerV1V2)
#
#  dropout_2 (Dropout)         (None, 1280)              0
#
#  dense_2 (Dense)             (None, 3)                 3843
#
# ...
# Total params: 3,416,867
# Trainable params: 3,843
# Non-trainable params: 3,413,024
# _________________________________________________________________
# None
# Epoch 1/5
# 74/74 [==============================] - 78s 1s/step - loss: 0.7246 - accuracy: 0.7462
# Epoch 2/5
# ...

# %%
model.export(export_dir='.', export_format=ExportFormat.LABEL)
# Out:
# INFO:tensorflow:Saving labels in ./labels.txt
# INFO:tensorflow:Saving labels in ./labels.txt

# %%
data = DataLoader.from_folder('/content/drive/MyDrive/intern/katunda_dataset/leaves_dataset')
train_data, test_data = data.split(0.8)
model = image_classifier.create(train_data)
loss, accuracy = model.evaluate(test_data)
model.export('leaves_classifier.tflite', 'leaf_labels.txt')
# Out:
# INFO:tensorflow:Load image with size: 3274, num_label: 3, labels: Leaves_Brownspot, Leaves_Healthy, Leaves_Woodiness.
# INFO:tensorflow:Load image with size: 3274, num_label: 3, labels: Leaves_Brownspot, Leaves_Healthy, Leaves_Woodiness.
# INFO:tensorflow:Retraining the models...
# INFO:tensorflow:Retraining the models...
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hub_keras_layer_v1v2_1 (Hub  (None, 1280)             3413024
#  KerasLayerV1V2)
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  dense_1 (Dense)             (None, 3)                 3843
#
# ...
# Total params: 3,416,867
# Trainable params: 3,843
# Non-trainable params: 3,413,024
# _________________________________________________________________
# None
# Epoch 1/5
# 81/81 [==============================] - 398s 5s/step - loss: 0.6372 - accuracy: 0.8029
# Epoch 2/5
# ...

# %%
model.export(export_dir='.', export_format=ExportFormat.LABEL)
# Out:
# INFO:tensorflow:Saving labels in ./labels.txt
# INFO:tensorflow:Saving labels in ./labels.txt
